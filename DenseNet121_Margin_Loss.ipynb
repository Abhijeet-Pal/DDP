# %%
import os
root_path = '/raid/ee-mariyam/maryam/abhijeet/Combined_Files'
def get_jpg_paths(base_dir):
    jpg_dict = {}
    
    for folder_name in os.listdir(base_dir):
        folder_path = os.path.join(base_dir, folder_name)
        
        if os.path.isdir(folder_path):
            jpg_paths = []
            
            for file_name in os.listdir(folder_path):
                if file_name.lower().endswith('.jpg'):
                    file_path = os.path.join(folder_path, file_name)
                    jpg_paths.append(file_path)
            
            if jpg_paths:
                jpg_dict[folder_name] = jpg_paths
    
    return jpg_dict

combined_files_path = root_path
jpg_paths_dict = get_jpg_paths(combined_files_path)

# %%
import os
import torch
import torchvision.transforms as transforms
from torchvision import datasets, models
from torch.utils.data import DataLoader, random_split
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import confusion_matrix
import torch.nn.functional as F 
import cv2
from PIL import Image

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
def evaluate_model(model, val_loader):
    model.eval()
    all_labels = []
    all_preds = []
    
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
    
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)
    return all_labels, all_preds

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, num_classes, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, 
                xticklabels=class_names,
                yticklabels=class_names)
    
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

# %%
def plot_losses_and_accuracies(train_losses, val_losses, train_accuracies, val_accuracies):

    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='orange')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.grid()
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy', color='green')
    plt.plot(val_accuracies, label='Validation Accuracy', color='red')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.grid()
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_classwise_accuracy(cm, jpg_paths_dict):
    total_accuracy = np.trace(cm) / np.sum(cm)

    classwise_accuracy = cm.diagonal() / cm.sum(axis=1)

    class_names = list(jpg_paths_dict.keys())  
    classwise_accuracy = [
        acc if cm.sum(axis=1)[i] > 0 else np.nan
        for i, acc in enumerate(classwise_accuracy)
    ]

    print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
    for i, accuracy in enumerate(classwise_accuracy):
        if np.isnan(accuracy):
            print(f"Class '{class_names[i]}' Accuracy: N/A (no samples)")
        else:
            print(f"Class '{class_names[i]}' Accuracy: {accuracy * 100:.2f}%")

    plt.figure(figsize=(10, 6))
    plt.bar(class_names, classwise_accuracy, color='skyblue')
    plt.ylabel('Accuracy')
    plt.title('Class-wise Accuracy')
    plt.ylim(0, 1)  
    plt.axhline(total_accuracy, color='red', linestyle='--', label='Total Accuracy')
    plt.xticks(rotation=45) 
    plt.legend()
    plt.grid(axis='y')
    plt.tight_layout()  
    plt.show()

# %%
for subfolder, jpg_files in jpg_paths_dict.items():
    print(f"Subfolder: {subfolder}")
    print(f"Number of JPEG files: {len(jpg_files)}")
    print()
# Out:
# Subfolder: Purple_Blotch
# Number of JPEG files: 406
#
# Subfolder: Thrips
# Number of JPEG files: 546
#
# Subfolder: IYSV
# Number of JPEG files: 754
#
# Subfolder: Twister
# Number of JPEG files: 317
#
# Subfolder: Healthy
# Number of JPEG files: 1072
#
# Subfolder: Bulb Rot
# Number of JPEG files: 669
#
# Subfolder: Basal_Rot
# Number of JPEG files: 140
#
# Subfolder: Stemphylium
# Number of JPEG files: 661
#
# Subfolder: Anthracnose
# Number of JPEG files: 765

# %%
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

class CustomImageDataset(Dataset):
    def __init__(self, jpg_files_dict, transform=None):
        self.transform = transform
        self.image_paths = []
        self.labels = []
        self.label_map = {}
        self._prepare_data(jpg_files_dict)

    def _prepare_data(self, jpg_files_dict):
        for label_idx, (subfolder, file_paths) in enumerate(jpg_files_dict.items()):
            self.label_map[subfolder] = label_idx
            for file_path in file_paths:
                self.image_paths.append(file_path)
                self.labels.append(label_idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        try:
            image = Image.open(img_path).convert('RGB')
        except (OSError, IOError) as e:
            print(f'Error loading image {img_path}: {e}')
            image = Image.new('RGB', (224, 224))
            label = self.labels[idx]
        else:
            label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

class CustomImageDataset(Dataset):
    def __init__(self, jpg_files_dict, transform=None):
        self.transform = transform
        self.image_paths = []
        self.labels = []
        self.label_map = {}
        self._prepare_data(jpg_files_dict)

    def _prepare_data(self, jpg_files_dict):
        for label_idx, (subfolder, file_paths) in enumerate(jpg_files_dict.items()):
            self.label_map[subfolder] = label_idx
            for file_path in file_paths:
                self.image_paths.append(file_path)
                self.labels.append(label_idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        try:
            image = Image.open(img_path).convert('RGB')
        except (OSError, IOError) as e:
            print(f'Error loading image {img_path}: {e}')
            image = Image.new('RGB', (224, 224))
            label = self.labels[idx]
        else:
            label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

jpg_paths_comb_dict = jpg_paths_dict.copy()
anthra = jpg_paths_comb_dict['Anthracnose']
twist = jpg_paths_comb_dict['Twister']
antra_twist = anthra+twist
jpg_paths_comb_dict['Antracnose_Twister'] = antra_twist

jpg_paths_comb_dict.pop('Anthracnose', None)
jpg_paths_comb_dict.pop('Twister', None)

for subfolder, jpg_files in jpg_paths_comb_dict.items():
    print(f"Subfolder: {subfolder}")
    print(f"Number of JPEG files: {len(jpg_files)}")
    print()
dataset = CustomImageDataset(jpg_files_dict=jpg_paths_comb_dict, transform=transform)
# Out:
# Subfolder: Purple_Blotch
# Number of JPEG files: 406
#
# Subfolder: Thrips
# Number of JPEG files: 546
#
# Subfolder: IYSV
# Number of JPEG files: 754
#
# Subfolder: Healthy
# Number of JPEG files: 1072
#
# Subfolder: Bulb Rot
# Number of JPEG files: 669
#
# Subfolder: Basal_Rot
# Number of JPEG files: 140
#
# Subfolder: Stemphylium
# Number of JPEG files: 661
#
# Subfolder: Antracnose_Twister
# Number of JPEG files: 1082

# %%
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=32)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=32)

# %%
import numpy as np
import torch
class_counts = []
for subfolder, jpg_files in jpg_paths_comb_dict.items():
    class_counts.append(len(jpg_files))
def compute_class_weights(label_map, dataset):
    print(class_counts)
    class_weights = np.max(class_counts) / class_counts
    class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
    print(class_weights)
    return class_weights

class_weights = compute_class_weights(dataset.label_map, dataset)
criterion = nn.CrossEntropyLoss(weight=class_weights)
# Out:
# [406, 546, 754, 1072, 669, 140, 661, 1082]
# tensor([2.6650, 1.9817, 1.4350, 1.0093, 1.6173, 7.7286, 1.6369, 1.0000],
#        device='cuda:0')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models

model = models.densenet121(pretrained=True)


in_features = model.classifier.in_features  

mlp_classifier = nn.Sequential(
    nn.Linear(in_features, 512),  
    nn.ReLU(),                   
    nn.Dropout(0.5),              
    nn.Linear(512, 256),         
    nn.ReLU(),                    
    nn.Dropout(0.5),              
    nn.Linear(256, num_classes)   
)

model.classifier = mlp_classifier

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=5):
    best_acc = 0.0
    
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            corrects += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects / total

        model.eval()
        val_running_loss = 0.0
        val_corrects = 0
        val_total = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                
                val_running_loss += loss.item() * inputs.size(0)
                
                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_corrects += (predicted == labels).sum().item()

        val_loss = val_running_loss / len(val_loader.dataset)
        val_acc = val_corrects / val_total

        train_losses.append(epoch_loss)
        val_losses.append(val_loss)
        train_accuracies.append(epoch_acc)
        val_accuracies.append(val_acc)

        print(f'Epoch {epoch + 1}/{num_epochs} '
              f'Train Loss: {epoch_loss:.4f} Train Accuracy: {epoch_acc:.4f} '
              f'Val Loss: {val_loss:.4f} Val Accuracy: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), 'denset121_twister_anthracnose_combined_mlp.pth')
            print(f'Saved best model with accuracy: {best_acc:.4f}')

    print('Training complete.')
    print(f'Best Validation Accuracy: {best_acc:.4f}')
    return train_losses, val_losses, train_accuracies, val_accuracies


train_losses, val_losses, train_accuracies, val_accuracies = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20)


plot_losses_and_accuracies(train_losses, val_losses, train_accuracies, val_accuracies)
model.load_state_dict(torch.load('denset121_twister_anthracnose_combined.pth'))
all_labels, all_preds = evaluate_model(model, val_loader)
cm = confusion_matrix(all_labels, all_preds)
class_names = jpg_paths_comb_dict.keys()
num_classes=len(jpg_paths_comb_dict)
plot_confusion_matrix(cm, num_classes , class_names )
plot_classwise_accuracy(cm, jpg_paths_comb_dict)
# Out:
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 1/20 Train Loss: 1.4054 Train Accuracy: 0.5213 Val Loss: 0.8734 Val Accuracy: 0.7486
# Saved best model with accuracy: 0.7486
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 2/20 Train Loss: 0.8163 Train Accuracy: 0.7240 Val Loss: 0.5807 Val Accuracy: 0.8227
# Saved best model with accuracy: 0.8227
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 76
#      72     print(f'Best Validation Accuracy: {best_acc:.4f}')
#      73     return train_losses, val_losses, train_accuracies, val_accuracies
# ---> 76 train_losses, val_losses, train_accuracies, val_accuracies = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20)
#      79 plot_losses_and_accuracies(train_losses, val_losses, train_accuracies, val_accuracies)
#      80 model.load_state_dict(torch.load('denset121_twister_anthracnose_combined.pth'))
#
# Cell In[18], line 42, in train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs)
#      39 val_total = 0
#      41 with torch.no_grad():
# ---> 42     for inputs, labels in val_loader:
#      43         inputs, labels = inputs.to(device), labels.to(device)
#      44         outputs = model(inputs)
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1328, in _MultiProcessingDataLoaderIter._next_data(self)
#    1325     return self._process_data(data)
#    1327 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1328 idx, data = self._get_data()
#    1329 self._tasks_outstanding -= 1
#    1330 if self._dataset_kind == _DatasetKind.Iterable:
#    1331     # Check for _IterableDatasetStopIteration
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1294, in _MultiProcessingDataLoaderIter._get_data(self)
#    1290     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1291     # need to call `.task_done()` because we don't use `.join()`.
#    1292 else:
#    1293     while True:
# -> 1294         success, data = self._try_get_data()
#    1295         if success:
#    1296             return data
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1132, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1119 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1120     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1121     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1129     # Returns a 2-tuple:
#    1130     #   (bool: whether successfully get data, any: data if successful else None)
#    1131     try:
# -> 1132         data = self._data_queue.get(timeout=timeout)
#    1133         return (True, data)
#    1134     except Exception as e:
#    1135         # At timeout and error, we manually check whether any worker has
#    1136         # failed. Note that this is the only mechanism for Windows to detect
#    1137         # worker failures.
#
# File ~/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/queues.py:107, in Queue.get(self, block, timeout)
#     105 if block:
#     106     timeout = deadline - time.monotonic()
# --> 107     if not self._poll(timeout):
#     108         raise Empty
#     109 elif not self._poll():
#
# File ~/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File ~/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File ~/miniconda3/envs/abhijeet/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
plot_losses_and_accuracies(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
model.load_state_dict(torch.load('denset121_twister_anthracnose_combined_mlp.pth'))
all_labels, all_preds = evaluate_model(model, val_loader)
# Out:
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file

# %%
cm = confusion_matrix(all_labels, all_preds)
class_names = jpg_paths_comb_dict.keys()
num_classes=len(jpg_paths_comb_dict)
plot_confusion_matrix(cm, num_classes , class_names )

# %%
plot_classwise_accuracy(cm, jpg_paths_comb_dict)
# Out:
# Total Accuracy: 96.44%
# Class 'Purple_Blotch' Accuracy: 80.00%
# Class 'Thrips' Accuracy: 100.00%
# Class 'IYSV' Accuracy: 99.36%
# Class 'Healthy' Accuracy: 100.00%
# Class 'Bulb Rot' Accuracy: 100.00%
# Class 'Basal_Rot' Accuracy: 96.88%
# Class 'Stemphylium' Accuracy: 90.30%
# Class 'Antracnose_Twister' Accuracy: 97.24%

# %% [markdown]
# # Margin loss

# %%
class MarginLoss(nn.Module):
    def __init__(self, margin=1.0, num_classes=None):
        super(MarginLoss, self).__init__()
        self.margin = margin
        self.num_classes = num_classes

    def forward(self, logits, targets):

        batch_size = logits.size(0)
        true_scores = logits[torch.arange(batch_size), targets] 

        true_scores_expanded = true_scores.unsqueeze(1).expand(-1, self.num_classes)  

        margins = self.margin + logits - true_scores_expanded
        margins = torch.clamp(margins, min=0)  
        margins[torch.arange(batch_size), targets] = 0 

        loss = margins.sum(dim=1).mean()
        return loss

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models

model = models.densenet121(pretrained=True)

in_features = model.classifier.in_features  

mlp_classifier = nn.Sequential(
    nn.Linear(in_features, 512),  
    nn.ReLU(),                    
    nn.Dropout(0.5),             
    nn.Linear(512, 256),          
    nn.ReLU(),                    
    nn.Dropout(0.5),            
    nn.Linear(256, num_classes) 
)

model.classifier = mlp_classifier

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

criterion = MarginLoss(margin=1.0, num_classes=num_classes)

optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

# %%
def train_model_with_margin_loss(model, train_loader, val_loader, criterion, optimizer, num_epochs=5):
    best_acc = 0.0
    
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels) 

            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            corrects += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects / total

        model.eval()
        val_running_loss = 0.0
        val_corrects = 0
        val_total = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)  
                
                val_running_loss += loss.item() * inputs.size(0)
                
                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_corrects += (predicted == labels).sum().item()

        val_loss = val_running_loss / len(val_loader.dataset)
        val_acc = val_corrects / val_total

        train_losses.append(epoch_loss)
        val_losses.append(val_loss)
        train_accuracies.append(epoch_acc)
        val_accuracies.append(val_acc)

        print(f'Epoch {epoch + 1}/{num_epochs} '
              f'Train Loss: {epoch_loss:.4f} Train Accuracy: {epoch_acc:.4f} '
              f'Val Loss: {val_loss:.4f} Val Accuracy: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), 'denset121_twister_anthracnose_combined_mlp_margin_loss.pth')
            print(f'Saved best model with accuracy: {best_acc:.4f}')

    print('Training complete.')
    print(f'Best Validation Accuracy: {best_acc:.4f}')
    return train_losses, val_losses, train_accuracies, val_accuracies


train_losses, val_losses, train_accuracies, val_accuracies = train_model_with_margin_loss(
    model, train_loader, val_loader, criterion, optimizer, num_epochs=20
)
# Out:
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 1/20 Train Loss: 2.5432 Train Accuracy: 0.5626 Val Loss: 1.0268 Val Accuracy: 0.7495
# Saved best model with accuracy: 0.7495
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 2/20 Train Loss: 1.1274 Train Accuracy: 0.7460 Val Loss: 0.6793 Val Accuracy: 0.8293
# Saved best model with accuracy: 0.8293
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 3/20 Train Loss: 0.8890 Train Accuracy: 0.7875 Val Loss: 0.5663 Val Accuracy: 0.8424
# Saved best model with accuracy: 0.8424
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 4/20 Train Loss: 0.7762 Train Accuracy: 0.8100 Val Loss: 0.5380 Val Accuracy: 0.8490
# Saved best model with accuracy: 0.8490
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 5/20 Train Loss: 0.7361 Train Accuracy: 0.8157 Val Loss: 0.5543 Val Accuracy: 0.8499
# Saved best model with accuracy: 0.8499
# Exception ignored in: Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0><function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>Traceback (most recent call last):
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# Traceback (most recent call last):
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     Exception ignored in: Exception ignored in: Exception ignored in: Traceback (most recent call last):
# self._shutdown_workers()      File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
# self._shutdown_workers()<function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0><function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0><function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#
#
#
#     self._shutdown_workers()  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# if w.is_alive():
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     if w.is_alive():      File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     self._shutdown_workers()
# self._shutdown_workers()    if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# self._shutdown_workers()  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#         if w.is_alive():AssertionError
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# assert self._parent_pid == os.getpid(), 'can only test a child process'if w.is_alive():
# : AssertionError
# can only test a child process  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
#     : AssertionErrorif w.is_alive():  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
# can only test a child process:
#       File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child processException ignored in: assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>AssertionError
# Exception ignored in: assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# AssertionError: can only test a child process
# Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>:
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()    :
# self._shutdown_workers()  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         if w.is_alive():
# if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# Exception ignored in:     assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
#     AssertionError: assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
# Exception ignored in:
# AssertionErrorException ignored in: : can only test a child process<function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
#
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>    self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>if w.is_alive():
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# can only test a child process
#     Traceback (most recent call last):
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
# AssertionError    : self._shutdown_workers()can only test a child process
# Exception ignored in:
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# if w.is_alive():Traceback (most recent call last):
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#         self._shutdown_workers()
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# can only test a child processAssertionError
#     Exception ignored in: Traceback (most recent call last):
#
# if w.is_alive():<function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>:   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
# can only test a child processTraceback (most recent call last):
# Traceback (most recent call last):
#       File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# Exception ignored in:
#
# self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# Exception ignored in:       File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# self._shutdown_workers()<function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
#
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>Exception ignored in:   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     Traceback (most recent call last):
# if w.is_alive():<function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
#
# if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#     AssertionErrorself._shutdown_workers(): Traceback (most recent call last):
#
# can only test a child process  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
#         if w.is_alive():self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
# Exception ignored in:       File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():    assert self._parent_pid == os.getpid(), 'can only test a child process'
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
#
#     Traceback (most recent call last):
#     assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError: assert self._parent_pid == os.getpid(), 'can only test a child process'
# can only test a child process
# AssertionError
# : can only test a child process  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# Traceback (most recent call last):
# assert self._parent_pid == os.getpid(), 'can only test a child process'      File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     Exception ignored in:
# self._shutdown_workers()
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>Exception ignored in:
# AssertionError  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# : AssertionError    self._shutdown_workers()
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>:
# if w.is_alive():can only test a child processTraceback (most recent call last):
# self._shutdown_workers()
# Traceback (most recent call last):
#
# Exception ignored in:
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'    self._shutdown_workers()self._shutdown_workers()Traceback (most recent call last):
#
# if w.is_alive():
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# AssertionError
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# :         can only test a child process        self._shutdown_workers()if w.is_alive():
# assert self._parent_pid == os.getpid(), 'can only test a child process'if w.is_alive():
#
#
#
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# AssertionError  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     : Exception ignored in:     assert self._parent_pid == os.getpid(), 'can only test a child process'    can only test a child process<function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>assert self._parent_pid == os.getpid(), 'can only test a child process'
# if w.is_alive():
#
# AssertionError
#
# Traceback (most recent call last):
#
# : AssertionError  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# can only test a child process  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# can only test a child process:
# can only test a child processassert self._parent_pid == os.getpid(), 'can only test a child process'self._shutdown_workers()
#
#
# AssertionError  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# :     can only test a child processif w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#
# AssertionError    : can only test a child process
#
# if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0><function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()Traceback (most recent call last):
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>if w.is_alive():
# if w.is_alive():
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#         assert self._parent_pid == os.getpid(), 'can only test a child process'self._shutdown_workers()
#
# AssertionError  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
# :     can only test a child processif w.is_alive():
#
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>AssertionError  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
# : can only test a child process
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#         assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionErrorself._shutdown_workers(): can only test a child process
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
# Exception ignored in:   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>    self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#     Traceback (most recent call last):
# if w.is_alive():
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     self._shutdown_workers()
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
# AssertionError    : can only test a child processif w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# Exception ignored in: AssertionError: can only test a child process
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
# if w.is_alive():  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
# self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# AssertionError    if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# :     assert self._parent_pid == os.getpid(), 'can only test a child process'
# can only test a child processAssertionError
# :     can only test a child process
# self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionErrorException ignored in: : <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>can only test a child process
# Exception ignored in:
# Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
#     self._shutdown_workers()Traceback (most recent call last):
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         self._shutdown_workers()if w.is_alive():
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#         if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# AssertionError:     can only test a child processassert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>assert self._parent_pid == os.getpid(), 'can only test a child process'Exception ignored in:
#
# Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>AssertionError  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# : can only test a child process
#
# self._shutdown_workers()Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
#       File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# self._shutdown_workers()
# if w.is_alive():  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# Exception ignored in:
#     <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>if w.is_alive():  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
# Traceback (most recent call last):
#
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#       File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# self._shutdown_workers()assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
#
# AssertionError  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# : :     can only test a child processcan only test a child process
# if w.is_alive():
#
# Exception ignored in:   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# assert self._parent_pid == os.getpid(), 'can only test a child process'Traceback (most recent call last):
#
# AssertionError  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     : self._shutdown_workers()can only test a child process
#
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# Traceback (most recent call last):
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process  File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
# self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#     self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# AssertionError    if w.is_alive():
# : can only test a child process  File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 6/20 Train Loss: 0.6930 Train Accuracy: 0.8274 Val Loss: 0.4881 Val Accuracy: 0.8649
# Saved best model with accuracy: 0.8649
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 7/20 Train Loss: 0.6322 Train Accuracy: 0.8356 Val Loss: 0.4504 Val Accuracy: 0.8630
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 8/20 Train Loss: 0.6144 Train Accuracy: 0.8398 Val Loss: 0.5700 Val Accuracy: 0.8527
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 9/20 Train Loss: 0.6284 Train Accuracy: 0.8375 Val Loss: 0.5099 Val Accuracy: 0.8555
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 10/20 Train Loss: 0.5388 Train Accuracy: 0.8630 Val Loss: 0.4621 Val Accuracy: 0.8612
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 11/20 Train Loss: 0.4880 Train Accuracy: 0.8666 Val Loss: 0.3923 Val Accuracy: 0.8809
# Saved best model with accuracy: 0.8809
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 12/20 Train Loss: 0.5007 Train Accuracy: 0.8623 Val Loss: 0.4353 Val Accuracy: 0.8640
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 13/20 Train Loss: 0.5009 Train Accuracy: 0.8614 Val Loss: 0.4015 Val Accuracy: 0.8762
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 14/20 Train Loss: 0.5414 Train Accuracy: 0.8581 Val Loss: 0.4239 Val Accuracy: 0.8752
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 15/20 Train Loss: 0.5063 Train Accuracy: 0.8640 Val Loss: 0.3573 Val Accuracy: 0.8780
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 16/20 Train Loss: 0.4745 Train Accuracy: 0.8696 Val Loss: 0.4132 Val Accuracy: 0.8743
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 17/20 Train Loss: 0.4834 Train Accuracy: 0.8717 Val Loss: 0.3625 Val Accuracy: 0.8874
# Saved best model with accuracy: 0.8874
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 18/20 Train Loss: 0.5015 Train Accuracy: 0.8666 Val Loss: 0.4730 Val Accuracy: 0.8602
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 19/20 Train Loss: 0.4781 Train Accuracy: 0.8696 Val Loss: 0.4558 Val Accuracy: 0.8602
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 20/20 Train Loss: 0.4506 Train Accuracy: 0.8745 Val Loss: 0.3893 Val Accuracy: 0.8893
# Saved best model with accuracy: 0.8893
# Training complete.
# Best Validation Accuracy: 0.8893

# %%
plot_losses_and_accuracies(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
model.load_state_dict(torch.load('denset121_twister_anthracnose_combined_mlp_margin_loss.pth'))
all_labels, all_preds = evaluate_model(model, val_loader)
# Out:
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file

# %%
cm = confusion_matrix(all_labels, all_preds)
class_names = jpg_paths_comb_dict.keys()
num_classes = len(jpg_paths_comb_dict)

plot_confusion_matrix(cm, num_classes, class_names)
plot_classwise_accuracy(cm, jpg_paths_comb_dict)
# Out:
# Total Accuracy: 88.93%
# Class 'Purple_Blotch' Accuracy: 62.67%
# Class 'Thrips' Accuracy: 98.26%
# Class 'IYSV' Accuracy: 100.00%
# Class 'Healthy' Accuracy: 99.55%
# Class 'Bulb Rot' Accuracy: 100.00%
# Class 'Basal_Rot' Accuracy: 0.00%
# Class 'Stemphylium' Accuracy: 76.43%
# Class 'Antracnose_Twister' Accuracy: 92.89%

# %% [markdown]
# # Margin without MLP

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models

model = models.densenet121(pretrained=True)

num_classes = len(jpg_paths_comb_dict)

model.classifier = nn.Linear(model.classifier.in_features, num_classes)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

criterion = MarginLoss(margin=1.0, num_classes=num_classes)

optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

# %%
def train_model_with_margin_loss(model, train_loader, val_loader, criterion, optimizer, num_epochs=5):
    best_acc = 0.0
    
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        corrects = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels) 
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            corrects += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = corrects / total

        model.eval()
        val_running_loss = 0.0
        val_corrects = 0
        val_total = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels) 
                
                val_running_loss += loss.item() * inputs.size(0)
                
                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_corrects += (predicted == labels).sum().item()

        val_loss = val_running_loss / len(val_loader.dataset)
        val_acc = val_corrects / val_total

        train_losses.append(epoch_loss)
        val_losses.append(val_loss)
        train_accuracies.append(epoch_acc)
        val_accuracies.append(val_acc)

        print(f'Epoch {epoch + 1}/{num_epochs} '
              f'Train Loss: {epoch_loss:.4f} Train Accuracy: {epoch_acc:.4f} '
              f'Val Loss: {val_loss:.4f} Val Accuracy: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), 'denset121_twister_anthracnose_combined_margin_loss.pth')
            print(f'Saved best model with accuracy: {best_acc:.4f}')

    print('Training complete.')
    print(f'Best Validation Accuracy: {best_acc:.4f}')
    return train_losses, val_losses, train_accuracies, val_accuracies


train_losses, val_losses, train_accuracies, val_accuracies = train_model_with_margin_loss(
    model, train_loader, val_loader, criterion, optimizer, num_epochs=20
)
# Out:
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 1/20 Train Loss: 1.8623 Train Accuracy: 0.6900 Val Loss: 0.8980 Val Accuracy: 0.8124
# Saved best model with accuracy: 0.8124
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 2/20 Train Loss: 0.8608 Train Accuracy: 0.8157 Val Loss: 0.6933 Val Accuracy: 0.8377
# Saved best model with accuracy: 0.8377
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 3/20 Train Loss: 0.6521 Train Accuracy: 0.8487 Val Loss: 0.6000 Val Accuracy: 0.8452
# Saved best model with accuracy: 0.8452
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 4/20 Train Loss: 0.5930 Train Accuracy: 0.8551 Val Loss: 0.5128 Val Accuracy: 0.8668
# Saved best model with accuracy: 0.8668
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 5/20 Train Loss: 0.5048 Train Accuracy: 0.8708 Val Loss: 0.5317 Val Accuracy: 0.8649
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 6/20 Train Loss: 0.4688 Train Accuracy: 0.8811 Val Loss: 0.5073 Val Accuracy: 0.8659
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 7/20 Train Loss: 0.4326 Train Accuracy: 0.8856 Val Loss: 0.4656 Val Accuracy: 0.8799
# Saved best model with accuracy: 0.8799
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 8/20 Train Loss: 0.3881 Train Accuracy: 0.8942 Val Loss: 0.4487 Val Accuracy: 0.8931
# Saved best model with accuracy: 0.8931
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 9/20 Train Loss: 0.3561 Train Accuracy: 0.9081 Val Loss: 0.4058 Val Accuracy: 0.8931
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 10/20 Train Loss: 0.3531 Train Accuracy: 0.9060 Val Loss: 0.4418 Val Accuracy: 0.8827
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 11/20 Train Loss: 0.3399 Train Accuracy: 0.9109 Val Loss: 0.3920 Val Accuracy: 0.8931
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 12/20 Train Loss: 0.3168 Train Accuracy: 0.9130 Val Loss: 0.3620 Val Accuracy: 0.9137
# Saved best model with accuracy: 0.9137
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 13/20 Train Loss: 0.3138 Train Accuracy: 0.9116 Val Loss: 0.3671 Val Accuracy: 0.8968
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 14/20 Train Loss: 0.3248 Train Accuracy: 0.9095 Val Loss: 0.4448 Val Accuracy: 0.8837
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 15/20 Train Loss: 0.2889 Train Accuracy: 0.9226 Val Loss: 0.3678 Val Accuracy: 0.8884
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 16/20 Train Loss: 0.2852 Train Accuracy: 0.9146 Val Loss: 0.4200 Val Accuracy: 0.8874
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f47232660d0>
# Traceback (most recent call last):
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/raid/ee-mariyam/maryam/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/raid/ee-mariyam/maryam/miniconda3/envs/abhijeet/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 17/20 Train Loss: 0.2677 Train Accuracy: 0.9287 Val Loss: 0.3780 Val Accuracy: 0.8865
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 18/20 Train Loss: 0.2623 Train Accuracy: 0.9224 Val Loss: 0.3538 Val Accuracy: 0.9043
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 19/20 Train Loss: 0.2592 Train Accuracy: 0.9261 Val Loss: 0.4288 Val Accuracy: 0.8818
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7631.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7116.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7118.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7113.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7557.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_18_11_2023_DSC_7182.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7578.JPG: broken data stream when reading image file
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Epoch 20/20 Train Loss: 0.2458 Train Accuracy: 0.9271 Val Loss: 0.3624 Val Accuracy: 0.8996
# Training complete.
# Best Validation Accuracy: 0.9137

# %%
plot_losses_and_accuracies(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
model.load_state_dict(torch.load('denset121_twister_anthracnose_combined_margin_loss.pth'))
all_labels, all_preds = evaluate_model(model, val_loader)

cm = confusion_matrix(all_labels, all_preds)
class_names = jpg_paths_comb_dict.keys()
num_classes = len(jpg_paths_comb_dict)

plot_confusion_matrix(cm, num_classes, class_names)
plot_classwise_accuracy(cm, jpg_paths_comb_dict)
# Out:
# Error loading image /raid/ee-mariyam/maryam/abhijeet/Combined_Files/Purple_Blotch/PB_D_E6_21_11_2023_DSC_7698.JPG: broken data stream when reading image file
# Total Accuracy: 91.37%
# Class 'Purple_Blotch' Accuracy: 65.33%
# Class 'Thrips' Accuracy: 97.39%
# Class 'IYSV' Accuracy: 99.28%
# Class 'Healthy' Accuracy: 98.65%
# Class 'Bulb Rot' Accuracy: 100.00%
# Class 'Basal_Rot' Accuracy: 56.41%
# Class 'Stemphylium' Accuracy: 81.43%
# Class 'Antracnose_Twister' Accuracy: 92.42%
